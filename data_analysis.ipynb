# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/A. RESEARCH/Papers Luis Amigo/Eggers and Robledo 2023/rule_ai_based_coding_tools/data/Coding_tools_357.csv")

# %%
df.hist(column = "TC")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f52dd936490>]],
#       dtype=object)
