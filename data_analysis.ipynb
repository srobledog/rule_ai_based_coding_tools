# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/A. RESEARCH/Papers Luis Amigo/Eggers et al 2023/rule_ai_based_coding_tools/data/Coding_tools_357.csv")

# %%
df.hist(column = "TC")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1f1fbe5490>]],
#       dtype=object)

# %%
df["TC_log"] = np.log10(df["TC"] + 1)

# %%
df.hist(column = "TC_log")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1f1f39b810>]],
#       dtype=object)
